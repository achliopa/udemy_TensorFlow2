# %%
# Install and import TF2
# !pip install -q tensorflow==2.0.0
import tensorflow as tf
print(tf.__version__)
# Out:
#      |████████████████████████████████| 86.3MB 45kB/s
#      |████████████████████████████████| 3.8MB 44.2MB/s
#      |████████████████████████████████| 450kB 56.7MB/s
#      |████████████████████████████████| 81kB 10.1MB/s
# ERROR: tensorboard 2.0.2 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.10.0 which is incompatible.
# 2.0.0

# %%
# Additional imports
from tensorflow.keras.layers import Input,Dense,Flatten,SimpleRNN,GRU,LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD,Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load in the data
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
print("x_train.shape:",x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train.shape: (60000, 28, 28)

# %%
# Build the model

i = Input(shape=x_train[0].shape)
x = LSTM(128)(i)
x = Dense(10,activation='softmax')(x)

model = Model(i,x)

# %%
# compile and train
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
r = model.fit(x_train, y_train, validation_data=(x_test,y_test),epochs=10)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 105s 2ms/sample - loss: 0.3362 - accuracy: 0.8930 - val_loss: 0.1216 - val_accuracy: 0.9638
# Epoch 2/10
# 60000/60000 [==============================] - 102s 2ms/sample - loss: 0.1036 - accuracy: 0.9693 - val_loss: 0.0892 - val_accuracy: 0.9713
# Epoch 3/10
# 60000/60000 [==============================] - 104s 2ms/sample - loss: 0.0709 - accuracy: 0.9790 - val_loss: 0.0730 - val_accuracy: 0.9789
# Epoch 4/10
# 60000/60000 [==============================] - 104s 2ms/sample - loss: 0.0564 - accuracy: 0.9829 - val_loss: 0.0531 - val_accuracy: 0.9826
# Epoch 5/10
# 60000/60000 [==============================] - 104s 2ms/sample - loss: 0.0440 - accuracy: 0.9868 - val_loss: 0.0595 - val_accuracy: 0.9835
# Epoch 6/10
# 60000/60000 [==============================] - 103s 2ms/sample - loss: 0.0367 - accuracy: 0.9888 - val_loss: 0.0537 - val_accuracy: 0.9836
# Epoch 7/10
# 60000/60000 [==============================] - 104s 2ms/sample - loss: 0.0331 - accuracy: 0.9896 - val_loss: 0.0589 - val_accuracy: 0.9828
# Epoch 8/10
# 60000/60000 [==============================] - 103s 2ms/sample - loss: 0.0269 - accuracy: 0.9919 - val_loss: 0.0452 - val_accuracy: 0.9873
# Epoch 9/10
# 60000/60000 [==============================] - 103s 2ms/sample - loss: 0.0240 - accuracy: 0.9927 - val_loss: 0.0393 - val_accuracy: 0.9883
# Epoch 10/10
# 60000/60000 [==============================] - 104s 2ms/sample - loss: 0.0214 - accuracy: 0.9933 - val_loss: 0.0489 - val_accuracy: 0.9877

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Plot loss per iteration
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()
