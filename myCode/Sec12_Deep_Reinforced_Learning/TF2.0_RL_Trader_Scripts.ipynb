# %%
# Load scripts and data, install TF2
# !pip install -q tensorflow==2.0.0
# !wget https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/aapl_msi_sbux.csv
# !wget https://raw.githubusercontent.com/achliopa/udemy_TensorFlow2/master/myCode/Sec12_Deep_Reinforced_Learning/rl_trader.py
# !wget https://raw.githubusercontent.com/achliopa/udemy_TensorFlow2/master/myCode/Sec12_Deep_Reinforced_Learning/plot_rl_rewards.py
# Out:
#      |████████████████████████████████| 86.3MB 68kB/s
#      |████████████████████████████████| 450kB 51.6MB/s
#      |████████████████████████████████| 3.8MB 55.5MB/s
#      |████████████████████████████████| 81kB 11.3MB/s
# ERROR: tensorboard 2.0.2 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.10.0 which is incompatible.
# --2020-01-10 19:58:27--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/aapl_msi_sbux.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24098 (24K) [text/plain]
# Saving to: ‘aapl_msi_sbux.csv’
#
# ...

# %%
# Train RL Trader
# !python rl_trader.py -m train && plot_rl_rewards.py -m train
# Out:
# 2.0.0
# 2020-01-10 20:00:25.135469: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-01-10 20:00:25.139012: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-01-10 20:00:25.139234: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2c2ebc0 executing computations on platform Host. Devices:
# 2020-01-10 20:00:25.139268: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 7)]               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                256
# _________________________________________________________________
# ...

# %%
# Evaluate performance (2.5year episode)
# !python rl_trader.py -m test && plot_rl_rewards.py -m test
